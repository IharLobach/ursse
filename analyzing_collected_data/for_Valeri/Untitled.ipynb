# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from config_ursse import get_from_config
import os

# %%
path = "/mnt/c/Users/ilobach/OneDrive - Fermi National Accelerator Laboratory/URSSE/for_Valeri_long_memory_scope"
file_path = os.path.join(path, "RefCurve_2021-05-13_2_035149.Wfm.bin")

# %%
data = np.fromfile(file_path,dtype=np.float32)
ch1 = data[::2][1:]
ch2 = data[1::2][1:]

# %%
plt.plot(ch1[:20000])

# %%
plt.plot(ch2[:20000])
