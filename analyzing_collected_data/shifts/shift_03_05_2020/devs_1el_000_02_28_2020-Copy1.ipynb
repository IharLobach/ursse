# %%
import os
import sys
sys.path.append(os.path.join(os.getcwd(),'..','..','..'))
from ursse.hydra_harp_file_reader import HydraHarpFile
from ursse.LED_tests.data_analyzis import calc_Fano, get_time_window_hist, calc_Fano_from_counts_per_time_window
import numpy as np
import pandas as pd
import seaborn as sns
from ursse.data_processing import \
    get_event_delays, plot_arrival_time_hist, get_events_array, get_fanos, \
    plot_fanos_hist, process_file, read_event_delays, save_event_delays
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [15, 7.5]
plt.rcParams.update({'font.size': 16,'legend.fontsize':16})
import ursse.path_assistant as pa
shift = pa.PathAssistant('shift_02_28_2020')

# %%
df, n_revolutions = read_event_delays(shift.get_time_stamp_file_path('1el_000.ptu'))
t_delays = df.delay

# %%
gate = (61000, 67000)

# %%
n = 500
i = 200

# %%
plot_arrival_time_hist(t_delays[i*n:(i+1)*n], gate=gate, bins=1000, yscale='linear')

# %%
n_revolutions*133e-9
# Out:
# 19.955523224

# %%
from config_ursse import get_from_config
iota_period_sec = get_from_config("IOTA_revolution_period")
dt_sec = get_from_config("dt")
iota_period_au = iota_period_sec/dt_sec

# %%
from ursse.time_structure import get_bucket_gates, get_rate_in_gate_Hz,\
    reduce_df_to_one_gate, divide_df_into_time_bins, get_properties_in_time_bins

# %%
four_gates = get_bucket_gates(gate)
four_gates
# Out:
# [(61000.0, 67000.0),
#  (94250.0, 100250.0),
#  (127500.00000000001, 499.9999999999709),
#  (27750.0, 33750.0)]

# %%
get_rate_in_gate_Hz(df, n_revolutions, gate)
# Out:
# 24778.252840061938

# %%
df0 = reduce_df_to_one_gate(df, gate)
dt=0.025
df0 = divide_df_into_time_bins(df0, dt)
df0
# Out:
# /home/ilobach/ursse/analyzing_collected_data/shifts/shift_03_05_2020/../../../ursse/time_structure.py:36: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/ilobach/ursse/analyzing_collected_data/shifts/shift_03_05_2020/../../../ursse/time_structure.py:37: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/ilobach/ursse/analyzing_collected_data/shifts/shift_03_05_2020/../../../ursse/time_structure.py:38: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            revolution    delay  index_of_dt_bin  bin_time   time_sec
# 343               341  62850.0                0     0.000   0.000045
# 362               359  62975.0                0     0.000   0.000048
# 532               528  63734.0                0     0.000   0.000070
# 576               571  63891.0                0     0.000   0.000076
# 670               664  63050.0                0     0.000   0.000088
# ...               ...      ...              ...       ...        ...
# 150837837   149999249  62371.0              797    19.925  19.949900
# 150837842   149999253  62159.0              797    19.925  19.949901
# 150837866   149999276  62146.0              797    19.925  19.949904
# 150838014   149999423  61913.0              797    19.925  19.949923
# 150838564   149999970  63719.0              797    19.925  19.949996
#
# [494340 rows x 5 columns]

# %%
time_bins_df = get_properties_in_time_bins(df0)
time_bins_df
# Out:
#                  time_sec  count         std
# index_of_dt_bin
# 0                   0.000    661  578.881406
# 1                   0.025    623  636.258789
# 2                   0.050    615  563.221481
# 3                   0.075    636  596.832620
# 4                   0.100    632  637.461095
# ...                   ...    ...         ...
# 793                19.825    643  646.021910
# 794                19.850    612  729.986967
# 795                19.875    614  758.699332
# 796                19.900    604  828.195800
# 797                19.925    648  843.389379
#
# [798 rows x 3 columns]

# %%
sns.lineplot(data=time_bins_df, x='time_sec', y='count')

# %%
import plotly.express as px
fig = px.line(x=time_bins_df['time_sec'], y=time_bins_df['std']**2)
fig.show()
# Out:
# <div>
#
#
#             <div id="bd41152d-7cb6-4c3e-9808-412c80850faa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bd41152d-7cb6-4c3e-9808-412c80850faa")) {
#                     Plotly.newPlot(
#                         'bd41152d-7cb6-4c3e-9808-412c80850faa',
#                         [{"hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [0.0, 0.025000000000000248, 0.05000000000000049, 0.0750000000000006, 0.10000000000000099, 0.125, 0.15000000000000077, 0.17499999999999813, 0.20000000000000195, 0.22499999999999723, 0.25, 0.27500000000000324, 0.30000000000000193, 0.32499999999999735, 0.34999999999999626, 0.375, 0.4000000000000039, 0.4250000000000051, 0.4499999999999946, 0.47499999999999964, 0.5, 0.524999999999999, 0.5500000000000063, 0.5749999999999936, 0.6000000000000055, 0.625, 0.6499999999999937, 0.6750000000000071, 0.6999999999999926, 0.7250000000000068, 0.75, 0.7749999999999923, 0.8000000000000079, 0.8249999999999921, 0.8500000000000091, 0.875, 0.8999999999999893, 0.9250000000000013, 0.9499999999999998, 0.9750000000000114, 1.0, 1.0249999999999881, 1.0499999999999987, 1.075000000000003, 1.1000000000000127, 1.125, 1.1499999999999873, 1.174999999999991, 1.200000000000009, 1.2250000000000143, 1.25, 1.274999999999986, 1.2999999999999905, 1.3250000000000113, 1.3500000000000143, 1.375, 1.3999999999999853, 1.4249999999999847, 1.4500000000000142, 1.4750000000000147, 1.5, 1.5249999999999844, 1.5499999999999827, 1.575000000000016, 1.6000000000000156, 1.625, 1.6499999999999848, 1.6749999999999812, 1.7000000000000195, 1.7250000000000103, 1.75, 1.774999999999987, 1.799999999999979, 1.8250000000000222, 1.8500000000000123, 1.875, 1.8999999999999968, 1.9249999999999765, 1.950000000000024, 1.9749999999999963, 2.0, 2.025000000000006, 2.0499999999999763, 2.0750000000000237, 2.0999999999999974, 2.125, 2.150000000000009, 2.1749999999999754, 2.2000000000000246, 2.224999999999989, 2.25, 2.2750000000000115, 2.2999999999999736, 2.325000000000026, 2.3499999999999823, 2.375, 2.40000000000002, 2.424999999999973, 2.450000000000027, 2.4749999999999828, 2.5, 2.525000000000024, 2.5499999999999714, 2.5750000000000286, 2.5999999999999743, 2.625, 2.650000000000029, 2.674999999999971, 2.7000000000000295, 2.724999999999975, 2.75, 2.7750000000000288, 2.7999999999999696, 2.8250000000000313, 2.8499999999999686, 2.875, 2.900000000000033, 2.9249999999999705, 2.950000000000031, 2.9749999999999632, 3.0, 3.0250000000000363, 3.0499999999999687, 3.0750000000000313, 3.099999999999963, 3.125, 3.1500000000000337, 3.17499999999997, 3.2000000000000273, 3.224999999999966, 3.25, 3.2750000000000394, 3.299999999999969, 3.32500000000003, 3.3499999999999637, 3.375, 3.400000000000039, 3.424999999999968, 3.4500000000000135, 3.4749999999999592, 3.5, 3.5250000000000417, 3.549999999999982, 3.5750000000000246, 3.5999999999999632, 3.625, 3.650000000000044, 3.6749999999999976, 3.70000000000002, 3.724999999999958, 3.75, 3.7750000000000443, 3.799999999999985, 3.8250000000000117, 3.849999999999954, 3.875, 3.9000000000000417, 3.9250000000000096, 3.9499999999999886, 3.974999999999954, 4.0, 4.025000000000049, 4.050000000000009, 4.0749999999999975, 4.099999999999952, 4.125, 4.150000000000048, 4.175000000000031, 4.200000000000005, 4.2249999999999455, 4.25, 4.2750000000000465, 4.300000000000013, 4.32499999999999, 4.349999999999953, 4.375, 4.400000000000052, 4.425000000000019, 4.449999999999971, 4.474999999999949, 4.5, 4.525000000000051, 4.5500000000000345, 4.5749999999999735, 4.599999999999947, 4.625, 4.650000000000054, 4.675000000000017, 4.6999999999999655, 4.724999999999948, 4.75, 4.775000000000054, 4.800000000000023, 4.824999999999963, 4.8499999999999455, 4.875, 4.9000000000000545, 4.925000000000047, 4.949999999999957, 4.9749999999999455, 5.0, 5.025000000000054, 5.050000000000045, 5.0749999999999496, 5.099999999999945, 5.125, 5.150000000000058, 5.175000000000044, 5.199999999999952, 5.224999999999943, 5.25, 5.275000000000057, 5.300000000000045, 5.324999999999956, 5.34999999999994, 5.375, 5.400000000000057, 5.425000000000051, 5.449999999999947, 5.474999999999943, 5.5, 5.525000000000059, 5.550000000000052, 5.57499999 ...

# %%
sns.scatterplot(data=df0[(df0['time_sec']>13.4) & ((df0['time_sec']<13.7))], x="revolution_time", y='delay')

# %%
candidate_df = df0[(df0['time_sec']>13.4) & ((df0['time_sec']<13.55))]
candidate_df = candidate_df.reset_index(drop=True)

# %%
candidate_df['revolution'] = candidate_df['revolution']-candidate_df['revolution'][0]
candidate_df['time_sec'] = candidate_df['time_sec']-candidate_df['time_sec'][0]
candidate_df['index_of_dt_bin'] = candidate_df['index_of_dt_bin']-candidate_df['index_of_dt_bin'][0]
candidate_df['delay'] = candidate_df['delay']-candidate_df['delay'].mean()

# %%
candidate_df
# Out:
#       revolution        delay  index_of_dt_bin  time_sec  revolution_time
# 0              0 -1206.373692                0      0.00        13.405091
# 1            244  -443.373692                0      0.00        13.405123
# 2            334   -22.373692                0      0.00        13.405135
# 3            423   299.626308                0      0.00        13.405147
# 4            891  1584.626308                0      0.00        13.405210
# ...          ...          ...              ...       ...              ...
# 3530     1088116    22.626308               28      0.14        13.549810
# 3531     1088126   955.626308               28      0.14        13.549812
# 3532     1088514   756.626308               28      0.14        13.549863
# 3533     1088535   506.626308               28      0.14        13.549866
# 3534     1089361  -498.373692               28      0.14        13.549976
#
# [3535 rows x 5 columns]

# %%
sns.scatterplot(data=candidate_df.iloc[:100,:], x="revolution", y='delay')

# %%
len(candidate_df.index)
# Out:
# 3535

# %%
a0 = 0

# %%
from scipy.optimize import curve_fit
t0=2372
cand_df_slice = candidate_df.iloc[:100, :]
x = cand_df_slice["revolution"].values
y = cand_df_slice['delay'].values
def f(t, A, B, T):
    return np.exp(-a0*t)*(A*np.cos(2*np.pi/T*t)+B*np.sin(2*np.pi/T*t))
def f_damp(t, a0, A, B, T):
    return np.exp(-a0*t)*(A*np.cos(2*np.pi/T*t)+B*np.sin(2*np.pi/T*t))
p0 = (np.std(y), np.std(y), t0)
popt, pcov = curve_fit(f, x, y, p0=p0)
a, b, t = popt
x_fit = np.linspace(x[0],x[-1],10000)
y_fit = f_damp(x_fit, a0, a, b, t)
amp = np.sqrt(a**2+b**2)
amp, t, a0
# Out:
# (1370.4748475814301, 2361.2569740191693, 0)

# %%
b
# Out:
# 899.0753770336801

# %%
a0 = 0

cand_df_slice = candidate_df#[(candidate_df['revolution']<7e6)]

x = cand_df_slice["revolution"].values
y = cand_df_slice['delay'].values
x_fit = np.linspace(x[0],x[-1],10000)
y_fit = f_damp(x_fit, a0, a, b, t)
fig = px.scatter(cand_df_slice, x="revolution", y="delay")
fig.add_scatter(x=x_fit, y=y_fit, mode='lines')
fig.show()
# Out:
# <div>
#
#
#             <div id="8ec6e4c9-567a-48b6-8f77-92d93a7b560b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8ec6e4c9-567a-48b6-8f77-92d93a7b560b")) {
#                     Plotly.newPlot(
#                         '8ec6e4c9-567a-48b6-8f77-92d93a7b560b',
#                         [{"hovertemplate": "revolution=%{x}<br>delay=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [0, 244, 334, 423, 891, 1063, 1497, 1678, 1831, 2498, 2656, 2982, 2989, 3048, 3055, 3185, 3202, 3221, 3499, 3663, 4138, 4562, 4628, 4723, 5213, 5807, 6178, 6284, 6320, 6700, 7002, 7098, 7297, 7341, 7654, 7846, 7943, 8195, 8270, 8403, 8797, 8888, 8969, 9263, 9404, 9452, 9753, 9874, 10141, 10185, 10346, 10367, 10589, 10681, 10694, 10740, 10756, 10774, 11152, 11224, 11288, 11316, 11508, 11597, 11922, 11961, 12021, 12150, 12570, 12680, 12881, 13325, 13500, 13548, 13575, 14015, 14395, 14697, 15345, 15548, 15786, 15826, 16316, 16513, 16559, 16825, 16858, 17705, 18439, 18566, 18770, 18947, 18956, 19880, 20016, 21247, 21643, 21861, 22091, 22351, 22679, 23189, 24097, 24121, 24338, 24497, 24859, 24975, 25605, 26107, 26112, 26811, 26954, 27078, 27216, 27322, 27494, 27583, 27981, 28090, 28150, 28514, 28811, 28851, 29056, 29642, 29665, 30842, 30986, 30998, 31164, 31463, 31862, 32013, 32511, 32645, 33345, 33460, 33801, 33824, 33969, 33984, 34047, 34733, 35194, 35522, 35758, 35820, 36364, 36427, 36660, 37361, 37538, 37589, 38312, 38563, 39463, 39548, 39790, 40629, 41555, 41629, 41848, 41992, 42054, 42103, 42161, 42255, 42709, 42757, 42855, 43047, 43290, 43388, 43920, 44229, 44682, 44698, 44768, 44776, 44778, 44840, 45535, 45579, 46325, 46405, 46611, 47685, 47947, 48656, 48673, 48700, 48815, 49416, 49443, 49654, 50043, 50240, 50531, 50649, 51242, 51708, 52056, 52376, 53156, 53353, 53412, 53876, 53961, 54159, 54247, 54425, 54450, 54711, 55935, 56126, 56999, 57060, 57402, 57491, 57940, 57947, 58353, 58747, 59140, 59222, 59272, 59900, 60192, 60796, 60919, 61519, 61673, 61686, 61875, 61994, 62169, 62844, 63261, 63889, 64245, 64258, 64466, 65119, 65189, 65218, 65428, 65769, 65785, 66736, 67461, 67592, 67825, 68236, 68351, 68410, 68890, 69054, 69416, 69687, 70174, 70342, 70423, 70600, 70654, 70870, 71755, 71863, 72193, 72262, 72314, 72923, 73454, 74019, 74136, 74335, 74375, 74611, 75326, 75616, 75682, 76523, 76638, 76671, 76819, 77053, 77147, 77813, 78885, 79167, 79734, 80109, 80128, 80138, 80251, 80256, 80385, 80562, 81506, 81598, 81835, 81997, 82882, 83171, 83860, 84031, 84203, 84394, 84599, 84787, 86107, 86309, 86428, 86821, 86906, 87217, 88227, 88292, 88596, 89080, 90706, 91056, 91337, 91447, 92382, 92809, 93107, 93509, 93810, 94441, 94537, 94594, 94838, 95631, 96138, 96719, 97355, 97718, 97901, 98836, 99295, 99390, 100323, 100834, 100839, 101105, 102025, 102131, 102351, 102858, 103106, 103321, 103594, 103851, 104166, 104225, 104396, 104497, 104681, 105043, 105381, 106558, 107002, 107521, 107540, 107676, 107874, 109379, 109613, 109679, 110294, 110334, 110621, 110792, 111053, 111125, 111312, 111676, 112298, 112359, 113801, 113971, 114113, 114282, 114620, 114932, 115180, 115319, 116181, 116196, 117281, 117507, 117945, 118563, 118775, 119028, 119091, 119459, 119471, 119682, 120124, 120438, 120687, 120802, 121036, 122277, 122751, 122857, 123562, 123626, 123632, 125136, 125236, 125838, 126072, 126248, 126277, 126808, 127207, 127337, 127855, 127925, 128134, 128354, 128817, 129033, 129738, 130430, 130684, 130724, 131253, 131327, 131538, 131745, 133322, 133461, 133508, 134030, 135209, 135456, 136399, 136458, 136530, 137479, 137871, 138780, 139207, 139304, 139487, 139555, 139576, 139704, 140730, 140926, 140966, 142058, 142097, 142436, 142559, 142810, 143009, 143142, 143146, 143205, 143692, 144689, 144992, 145134, 145275, 145471, 145516, 145613, 145683, 145725, 145949, 146073, 146200, 147771, 148186, 148701, 149931, 150153, 150312, 150332, 150841, 150982, 151447, 151448, 151457, 151923, 152081, 152738, 152868, 152916, 153315, 153517, 153951, 154310, 154936, 155333, 155510, 155665, 156247, 156363, 156953, 158236, 158510, 159477, 159619, 159733, 159791, 160464, 160499, 160889, 161471, 161655, 162524, 162577, 162630, 1629 ...

# %%
a0/iota_period_sec
# Out:
# 1.8796992481203005

# %%
a0s = np.arange(-1e-6, 3e-6, 1e-7)
disc = [np.sum((y-f_damp(x, a0_, a, b, t))**2) for a0_ in a0s]
plt.plot(a0s, disc)
plt.yscale('log')

# %%
nbins=30
y_max = df0.groupby('index_of_dt_bin').delay.apply(lambda x: max(np.histogram(np.asarray(x), bins=nbins, range=gate)[0])).max()

# %%
bins = np.histogram([], bins=nbins, range=gate)[1]
bin_centers = (bins[1:]+bins[:-1])/2

# %%
hists = (df0.groupby('index_of_dt_bin').delay.apply(lambda x: np.histogram(np.asarray(x), bins=nbins, range=gate)[0])).to_list()

# %%
n_dt_bins = int(n_revolutions/revolutions_per_dt)

# %%
all_bin_centers = np.tile(bin_centers, n_dt_bins)
all_hists = np.concatenate(hists)[:nbins*n_dt_bins]
all_indexes = np.ravel(np.ones(bin_centers.shape)*(np.arange(n_dt_bins)[:, None])).astype(int)
hist_df = pd.DataFrame({'bin_center': all_bin_centers,
                        'counts': all_hists,
                        'time_index':all_indexes})
hist_df['time_sec'] = dt*hist_df['time_index']
y_max = hist_df['counts'].max()

# %%
hist_df
# Out:
#         bin_center  counts  time_index  time_sec
# 0          61100.0       0           0      0.00
# 1          61300.0       0           0      0.00
# 2          61500.0       0           0      0.00
# 3          61700.0       0           0      0.00
# 4          61900.0       0           0      0.00
# ...            ...     ...         ...       ...
# 119725     66100.0       0        3990     19.95
# 119726     66300.0       0        3990     19.95
# 119727     66500.0       0        3990     19.95
# 119728     66700.0       0        3990     19.95
# 119729     66900.0       0        3990     19.95
#
# [119730 rows x 4 columns]

# %%
fig = px.bar(hist_df, x="bin_center", y="counts",
  animation_frame="time_index", range_x=gate, range_y=[0, 1.1*y_max], labels={'x':'time, ps', 'y':'count'})
fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = int(dt*1000)
fig.layout.updatemenus[0].buttons[0].args[1]["transition"]["duration"] = 0
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-109-64cb04992dd1> in <module>
# ----> 1 fig = px.bar(hist_df, x="bin_center", y="counts",
#       2   animation_frame="time_index", range_x=gate, range_y=[0, 1.1*y_max], labels={'x':'time, ps', 'y':'count'})
#       3 fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = int(dt*1000)
#       4 fig.layout.updatemenus[0].buttons[0].args[1]["transition"]["duration"] = 0
#       5 fig.show()
#
# ~/ursse/env/lib/python3.8/site-packages/plotly/express/_chart_types.py in bar(data_frame, x, y, color, facet_row, facet_col, facet_col_wrap, hover_name, hover_data, custom_data, text, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, title, template, width, height)
#     307     mark.
#     308     """
# --> 309     return make_figure(
#     310         args=locals(),
#     311         constructor=go.Bar,
#
# ~/ursse/env/lib/python3.8/site-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1371     grouped = args["data_frame"].groupby(grouper, sort=False)
#    1372
# -> 1373     orders, sorted_group_names, sorted_group_values = get_orderings(
#    1374         args, grouper, grouped
#    1375     )
#
# ~/ursse/env/lib/python3.8/site-packages/plotly/express/_core.py in get_orderings(args, grouper, grouped)
#    1348                 else:
#    1349                     for val in uniques:
# -> 1350                         if val not in orders[col]:
#    1351                             orders[col].append(val)
#    1352                 group_values[col] = sorted(uniques, key=orders[col].index)
#
# KeyboardInterrupt:
